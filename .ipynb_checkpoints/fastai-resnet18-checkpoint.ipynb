# %%
# !nvidia-smi
# Out:
# Thu Mar 21 14:14:12 2019
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 418.39       Driver Version: 418.39       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   72C    P0    31W /  70W |   1988MiB / 15079MiB |      3%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |    0      1669      G   /usr/lib/xorg/Xorg                            80MiB |
# |    0      9331      C   .../qnkhuat/miniconda3/envs/dev/bin/python  1897MiB |
# +-----------------------------------------------------------------------------+

# %%
import gc

# %%
from fastai.vision import ImageDataBunch,ImageList,get_transforms,models,cnn_learner,accuracy

# %%
path ='/home/qnkhuat/data/emotion_compilation_split'

# %%
tfms = get_transforms(do_flip=True,flip_vert=False)

# %%
# ran this get erro in THcroe
data = (ImageDataBunch.from_folder(path,test='test',size=48,ds_tfms=tfms,bs=256)
       .normalize())

# %%
data.show_batch(rows=3)

# %%
learn = cnn_learner(data, models.resnet18)

# %%
learn.model_dir = '/home/qnkhuat/AI/vision/emotion_retrain/models'

# %%
learn.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
learn.metrics = [accuracy]

# %%
learn.fit(3,lr=1e-2)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='3', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/3 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='progress-bar-interrupted' max='380', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       Interrupted
#     </div>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-c549cddaaeb2> in <module>
# ----> 1 learn.fit(3,lr=1e-2)
#
# ~/miniconda3/envs/dev/lib/python3.6/site-packages/fastai/basic_train.py in fit(self, epochs, lr, wd, callbacks)
#     194         callbacks = [cb(self) for cb in self.callback_fns] + listify(callbacks)
#     195         if defaults.extra_callbacks is not None: callbacks += defaults.extra_callbacks
# --> 196         fit(epochs, self, metrics=self.metrics, callbacks=self.callbacks+callbacks)
#     197
#     198     def create_opt(self, lr:Floats, wd:Floats=0.)->None:
#
# ~/miniconda3/envs/dev/lib/python3.6/site-packages/fastai/basic_train.py in fit(epochs, learn, callbacks, metrics)
#      96             cb_handler.set_dl(learn.data.train_dl)
#      97             cb_handler.on_epoch_begin()
# ---> 98             for xb,yb in progress_bar(learn.data.train_dl, parent=pbar):
#      99                 xb, yb = cb_handler.on_batch_begin(xb, yb)
#     100                 loss = loss_batch(learn.model, xb, yb, learn.loss_func, learn.opt, cb_handler)
#
# ~/miniconda3/envs/dev/lib/python3.6/site-packages/fastprogress/fastprogress.py in __iter__(self)
#      66             for i,o in enumerate(self._gen):
#      67                 yield o
# ---> 68                 if self.auto_update: self.update(i+1)
#      69         except:
#      70             self.on_interrupt()
#
# ~/miniconda3/envs/dev/lib/python3.6/site-packages/fastprogress/fastprogress.py in update(self, val)
#      84             self.pred_t = avg_t * self.total
#      85             self.last_v,self.last_t = val,cur_t
# ---> 86             self.update_bar(val)
#      87             if not self.auto_update and val >= self.total:
#      88                 self.on_iter_end()
#
# ~/miniconda3/envs/dev/lib/python3.6/site-packages/fastprogress/fastprogress.py in update_bar(self, val)
#      96             warn("Your generator is empty.")
#      97             self.on_update(0, '100% [0/0]')
# ---> 98         else: self.on_update(val, f'{100 * val/self.total:.2f}% [{val}/{self.total} {elapsed_t}<{remaining_t}{end}]')
#      99
#     100
#
# ~/miniconda3/envs/dev/lib/python3.6/site-packages/fastprogress/fastprogress.py in on_update(self, val, text, interrupted)
#     168         self.progress = html_progress_bar(val, self.total, text, interrupted)
#     169         if self.display: self.out.update(HTML(self.progress))
# --> 170         elif self.parent is not None: self.parent.show()
#     171
#     172 class NBMasterBar(MasterBar):
#
# ~/miniconda3/envs/dev/lib/python3.6/site-packages/fastprogress/fastprogress.py in show(self)
#     206         to_show = [name for name in self.order if name in self.inner_dict.keys()]
#     207         self.html_code = '\n'.join([self.inner_dict[n] for n in to_show])
# --> 208         self.out.update(HTML(self.html_code))
#     209
#     210     def write(self, line, table=False):
#
# ~/miniconda3/envs/dev/lib/python3.6/site-packages/IPython/core/display.py in update(self, obj, **kwargs)
#     382             additional keyword arguments passed to update_display
#     383         """
# --> 384         update_display(obj, display_id=self.display_id, **kwargs)
#     385
#     386
#
# ~/miniconda3/envs/dev/lib/python3.6/site-packages/IPython/core/display.py in update_display(obj, display_id, **kwargs)
#     332     """
#     333     kwargs['update'] = True
# --> 334     display(obj, display_id=display_id, **kwargs)
#     335
#     336
#
# ~/miniconda3/envs/dev/lib/python3.6/site-packages/IPython/core/display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     309                 # kwarg-specified metadata gets precedence
#     310                 _merge(md_dict, metadata)
# --> 311             publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#     312     if display_id:
#     313         return DisplayHandle(display_id)
#
# ~/miniconda3/envs/dev/lib/python3.6/site-packages/IPython/core/display.py in publish_display_data(data, metadata, source, transient, **kwargs)
#     118         data=data,
#     119         metadata=metadata,
# --> 120         **kwargs
#     121     )
#     122
#
# ~/miniconda3/envs/dev/lib/python3.6/site-packages/ipykernel/zmqshell.py in publish(self, data, metadata, source, transient, update)
#     140
#     141         self.session.send(
# --> 142             self.pub_socket, msg, ident=self.topic,
#     143         )
#     144
#
# ~/miniconda3/envs/dev/lib/python3.6/site-packages/traitlets/traitlets.py in __get__(self, obj, cls)
#     543             return value
#     544
# --> 545     def __get__(self, obj, cls=None):
#     546         """Get the value of the trait by self.name for the instance.
#     547
#
# KeyboardInterrupt:

# %%
learn.fit_one_cycle(3,)
# Out:
# Total time: 01:33 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.940121</td>
#       <td>0.832881</td>
#       <td>0.694983</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.896163</td>
#       <td>0.807752</td>
#       <td>0.707776</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.872444</td>
#       <td>0.798682</td>
#       <td>0.708351</td>
#       <td>00:31</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.fit_one_cycle(3)
# Out:
# Total time: 01:34 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.897749</td>
#       <td>0.796183</td>
#       <td>0.710795</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.882040</td>
#       <td>0.787544</td>
#       <td>0.712376</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.856365</td>
#       <td>0.780812</td>
#       <td>0.714963</td>
#       <td>00:31</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.fit(3,lr=10e-3)
# Out:
# Total time: 01:34 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.975872</td>
#       <td>0.851729</td>
#       <td>0.697140</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.966671</td>
#       <td>0.889776</td>
#       <td>0.687653</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.946830</td>
#       <td>0.845354</td>
#       <td>0.687796</td>
#       <td>00:31</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.fit(3,lr=10e-3)
# Out:
# Total time: 01:33 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.918463</td>
#       <td>0.826771</td>
#       <td>0.704902</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.916019</td>
#       <td>0.828191</td>
#       <td>0.699152</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.920591</td>
#       <td>0.838965</td>
#       <td>0.704470</td>
#       <td>00:31</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.fit(5,lr=10e-3)
# Out:
# Total time: 02:38 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.894281</td>
#       <td>0.859081</td>
#       <td>0.704327</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.907095</td>
#       <td>0.903595</td>
#       <td>0.706483</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.877537</td>
#       <td>0.816046</td>
#       <td>0.714820</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.896085</td>
#       <td>0.797486</td>
#       <td>0.715826</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.906413</td>
#       <td>0.800432</td>
#       <td>0.718126</td>
#       <td>00:32</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.fit(5,lr=10e-3)
