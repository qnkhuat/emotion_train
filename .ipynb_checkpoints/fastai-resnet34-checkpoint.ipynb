# %%
import gc

# %%
from fastai.vision import ImageDataBunch,ImageList,get_transforms,models,cnn_learner,accuracy

# %%
path ='/home/qnkhuat/data/emotion_compilation_split'

# %%
tfms = get_transforms(do_flip=True,flip_vert=False)

# %%
# ran this get erro in THcroe
data = (ImageDataBunch.from_folder(path,test='test',size=48,ds_tfms=tfms,bs=256)
       .normalize())

# %%
data.show_batch(rows=3)
# Out:
# Exception ignored in: <bound method _DataLoaderIter.__del__ of <torch.utils.data.dataloader._DataLoaderIter object at 0x7f0ed39c32e8>>
# Traceback (most recent call last):
#   File "/home/qnkhuat/miniconda3/envs/dev/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 717, in __del__
#     self._shutdown_workers()
#   File "/home/qnkhuat/miniconda3/envs/dev/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 713, in _shutdown_workers
#     w.join()
#   File "/home/qnkhuat/miniconda3/envs/dev/lib/python3.6/multiprocessing/process.py", line 124, in join
#     res = self._popen.wait(timeout)
#   File "/home/qnkhuat/miniconda3/envs/dev/lib/python3.6/multiprocessing/popen_fork.py", line 50, in wait
#     return self.poll(os.WNOHANG if timeout == 0.0 else 0)
#   File "/home/qnkhuat/miniconda3/envs/dev/lib/python3.6/multiprocessing/popen_fork.py", line 28, in poll
#     pid, sts = os.waitpid(self.pid, flag)
# KeyboardInterrupt:

# %%
learn = cnn_learner(data, models.resnet34)

# %%
learn.model_dir = '/home/qnkhuat/AI/vision/emotion_retrain/models'

# %%
learn.lr_find()
learn.recorder.plot()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='2', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/2 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='95', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/95 00:00<00:00]
#     </div>

# %%
learn.metrics = [accuracy]

# %%
learn.fit(3,lr=1e-2)

# %%
learn.fit_one_cycle(6)

# %%
learn.unfreeze()

# %%
learn.lr_find()
learn.recorder.plot()

# %%
learn.fit_one_cycle(12)

# %%
learn.fit_one_cycle(3)

# %%
learn.fit(20,lr=10e-6)

# %%
learn.fit_one_cycle(3)
# Out:
# Total time: 00:48 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.801109</td>
#       <td>0.755753</td>
#       <td>0.729769</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.722545</td>
#       <td>0.639648</td>
#       <td>0.770160</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.638640</td>
#       <td>0.587517</td>
#       <td>0.787696</td>
#       <td>00:16</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.fit(20,lr=10e-6)
# Out:
# Total time: 05:41 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.588217</td>
#       <td>0.580909</td>
#       <td>0.787408</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.572399</td>
#       <td>0.574815</td>
#       <td>0.788989</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.568395</td>
#       <td>0.571505</td>
#       <td>0.792296</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.560826</td>
#       <td>0.568026</td>
#       <td>0.792152</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.557334</td>
#       <td>0.566723</td>
#       <td>0.793158</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.549105</td>
#       <td>0.562036</td>
#       <td>0.796464</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.538897</td>
#       <td>0.560790</td>
#       <td>0.797039</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.535602</td>
#       <td>0.556499</td>
#       <td>0.796176</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.526096</td>
#       <td>0.555482</td>
#       <td>0.798045</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.523066</td>
#       <td>0.553081</td>
#       <td>0.798045</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.522829</td>
#       <td>0.553744</td>
#       <td>0.796320</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.514147</td>
#       <td>0.549331</td>
#       <td>0.798476</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.507007</td>
#       <td>0.549547</td>
#       <td>0.798476</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.509834</td>
#       <td>0.544130</td>
#       <td>0.801495</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.503344</td>
#       <td>0.546038</td>
#       <td>0.802645</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.495686</td>
#       <td>0.544064</td>
#       <td>0.803076</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.493838</td>
#       <td>0.542495</td>
#       <td>0.802357</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.485001</td>
#       <td>0.538771</td>
#       <td>0.805232</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.483654</td>
#       <td>0.539746</td>
#       <td>0.804657</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.482284</td>
#       <td>0.539454</td>
#       <td>0.806813</td>
#       <td>00:18</td>
#     </tr>
#   </tbody>
# </table>
